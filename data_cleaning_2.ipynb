# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Additional Cleaning

# %%
# adjust for reading local file
contributions = pd.read_csv('contributions.csv')

# %%
contributions.head(2)
# Out:
#         Candidate State                       District     Office Type  \
# 0  HAGAN, MALLORY    AL  U.S. House Alabama District 3  Representative
# 1  HAGAN, MALLORY    AL  U.S. House Alabama District 3  Representative
#
#   Race Type Race Primary Election Date Primary Status Primary Runoff Status  \
# 0   Regular                     6/5/18       Advanced                  None
# 1   Regular                     6/5/18       Advanced                  None
#
#   General Status  Partisan Lean  ...  Tea Party Endorsed?  \
# 0  On the Ballot         -33.66  ...                  NaN
# 1  On the Ballot         -33.66  ...                  NaN
#
#   Main Street Endorsed? Chamber Endorsed? Candidate ID   Filer ID  \
# 0                   NaN               NaN    H8AL03054  C00502294
# 1                   NaN               NaN    H8AL03054  C00007542
#
#   Amendment indicator Primary-general indicator  \
# 0                   N                     P2018
# 1                   N                     P2018
#
#   Contributor/lender/transfer name Transaction date (MMDDYYYY) Transaction amt
# 0       MALLORY HAGAN FOR CONGRESS                   3262018.0             500
# 1                   HAGAN, MALLORY                   3132018.0            2500
#
# [2 rows x 52 columns]

# %%
df['Primary Status']
# Out:
# Candidate
# ALLEN, KATHLEEN           Lost
# ALLMAN, MICHAEL           Lost
# ALLRED, COLIN         Advanced
# ANDREI, LINDA             Lost
# ARMSTRONG, KELLY      Advanced
#                         ...
# WOODY, MICHAEL            Lost
# WRIGHT, JASON             Lost
# WYNES, JEREMY             Lost
# YOUNGBLOOD, TANZIE        Lost
# ZARKADES, TONY            Lost
# Name: Primary Status, Length: 299, dtype: object

# %%
df = contributions.copy()
df = df.drop(['Amendment indicator', 'Contributor/lender/transfer name', 'Transaction date (MMDDYYYY)'], axis = 1)
df = df.groupby(['Candidate']).agg({'Transaction amt': 'mean'})

to_drop = ['Candidate', 'Filer ID', 'Amendment indicator', 'Contributor/lender/transfer name', 'Transaction date (MMDDYYYY)', 'Transaction amt']
mask = np.isin(contributions.columns, to_drop, invert = True)
headings = contributions.columns

for i in range(len(headings)):
  if mask[i]:
    new_col = []
    for j in df.index:
      new_col.append(contributions[headings[i]][contributions['Candidate'] == j].iloc[0])
    df.insert(0, headings[i], new_col)

# %%
df = df.fillna(0)
df = df.replace({'Yes': 1, 'No': 0})
df = df.rename(columns = {'Transaction amt': 'Avg Donation Size'})
df.head(2)
# Out:
#                 Primary-general indicator Candidate ID  Chamber Endorsed?  \
# Candidate
# ALLEN, KATHLEEN                     P2018    H8GA07144                  0
# ALLMAN, MICHAEL                     P2018    H8CA52136                  0
#
#                  Main Street Endorsed?  Tea Party Endorsed?  \
# Candidate
# ALLEN, KATHLEEN                      0                    0
# ALLMAN, MICHAEL                      0                    0
#
#                  House Freedom Support?  Koch Support?  \
# Candidate
# ALLEN, KATHLEEN                       0              0
# ALLMAN, MICHAEL                       0              0
#
#                  Club for Growth Endorsed?  Susan B. Anthony Endorsed?  \
# Candidate
# ALLEN, KATHLEEN                          0                           0
# ALLMAN, MICHAEL                          0                           0
#
#                  Right to Life Endorsed?  ...  Partisan Lean  General Status  \
# Candidate                                 ...
# ALLEN, KATHLEEN                        0  ...         -12.73            None
# ALLMAN, MICHAEL                        0  ...           0.00            None
#
#                  Primary Runoff Status  Primary Status  \
# Candidate
# ALLEN, KATHLEEN                   None            Lost
# ALLMAN, MICHAEL                   None            Lost
#
#                  Race Primary Election Date  Race Type     Office Type  \
# Candidate
# ALLEN, KATHLEEN                     5/22/18    Regular  Representative
# ALLMAN, MICHAEL                      6/5/18    Regular  Representative
#
#                                           District  State  Avg Donation Size
# Candidate
# ALLEN, KATHLEEN      U.S. House Georgia District 7     GA             1000.0
# ALLMAN, MICHAEL  U.S. House California District 52     CA             2000.0
#
# [2 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['Primary-general indicator', 'Candidate ID', 'Chamber Endorsed?',
#        'Main Street Endorsed?', 'Tea Party Endorsed?',
#        'House Freedom Support?', 'Koch Support?', 'Club for Growth Endorsed?',
#        'Susan B. Anthony Endorsed?', 'Right to Life Endorsed?',
#        'NRA Endorsed?', 'Great America Endorsed?', 'Bannon Endorsed?',
#        'Trump Endorsed?', 'Rep Party Support?', 'No Labels Support?',
#        'VoteVets Endorsed?', 'WFP Endorsed?', 'Indivisible Endorsed?',
#        'PCCC Endorsed?', 'Justice Dems Endorsed?', 'Our Revolution Endorsed?',
#        'Sanders Endorsed?', 'Warren Endorsed? ', 'Biden Endorsed?',
#        'Guns Sense Candidate?', 'Emily Endorsed?', 'Party Support?',
#        'Obama Alum?', 'STEM?', 'Self-Funder?', 'Elected Official?', 'LGBTQ?',
#        'Veteran?', 'Race', 'Won Primary', 'Primary %', 'Partisan Lean',
#        'General Status', 'Primary Runoff Status', 'Primary Status',
#        'Race Primary Election Date', 'Race Type', 'Office Type', 'District',
#        'State', 'Avg Donation Size'],
#       dtype='object')

# %%
df.to_csv('average_donations.csv', index=False,)
